# %% [markdown]
# ## Игра "Угадай число"

# %%
from game_v2 import average_number

# %% [markdown]
# # Вычисляем среднее значение итераций для сходимости алгоритма бинарного поиска,
# # на массиве из 10 000 случайных чисел

# %%
average_number(1, 101)
# Out:
# Ваш алгоритм угадывает число в среднем за: 21 попытки

# %% [markdown]
# ## Игра "Угадай число"

# %%
from game_v2 import random_number

# %% [markdown]
# # Угадываем число, самостоятельно задавая границы начального интервала

# %%
random_number(100, 0)
# Out:
# Число было угадано
# Число попыток было:2
# 2

# %%
n = 10
f = n
z = f ** 2
f, z = z, f
